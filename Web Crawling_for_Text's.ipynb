# %% [markdown]
# ## Any Website is constructed with language HTML include :-
#
# the page design
# HTML is not a lanaguge its a structural tool to draw a block diagram
# css

# %% [markdown]
# ## to view the website page source without opening it using Click right --> vew page source, we can use `requests` library.
#
# `requests` library its used to send a HTTP requests using python. the
#
# `http requests` is a requests return a **Response object**
#
# `Response object` is an response include all the webpage source code include :-
#
#     1-content return the content of the response
#
#     2-close close the connection to the server
#
#     3-encoding
#
#     4-text return the text
#
#
# ## methods of the requests
#
# `requests.get` its used to send a `Get` request to the specified url.
#
# `requests.delete` its used to send a `delete` request to the specified url.

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import requests
resp = requests.get("https://www.youm7.com/story/2021/9/3/%D8%AA%D8%AF%D8%A7%D9%88%D9%84-%D8%A7%D9%84%D9%85%D9%86%D8%AA%D8%AC%D8%A7%D8%AA-%D8%A8%D8%A7%D9%84%D8%A8%D9%88%D8%B1%D8%B5%D8%A9-%D8%A7%D9%84%D8%B3%D9%84%D8%B9%D9%8A%D8%A9-%D9%8A%D9%86%D8%B7%D9%84%D9%82-%D8%A8%D8%A7%D9%84%D8%B1%D8%A8%D8%B9-%D8%A7%D9%84%D8%A3%D9%88%D9%84-%D9%85%D9%86-2022-%D9%87%D8%AF%D9%81%D9%87%D8%A7/5447650")
resp
# Out:
# <Response [200]>

# %% [markdown]
# ## Observation Responses number more than 200 means it successfully connected to the page

# %% [markdown]
# ## lets get the data or text inside this request

# %%
data = resp.text
data
# Out:
# '\r\n<!DOCTYPE html>\r\n<html>\r\n<head>\r\n    <title>تداول المنتجات بالبورصة السلعية ينطلق بالربع الأول من 2022.. هدفها تقليل حلقات تسليم السلع لتخفيض الأسعار.. وعقد توأمة مع بورصة بيلاروسيا للاستفادة من خبراتها.. وحسن السمعة شرط قيد الشركات مع تشجيع صغار التجار - اليوم السابع</title>\r\n    <meta http-equiv="Content-Type" content="charset=utf-8" />\r\n    <meta name=\'viewport\' content=\'width=1190\'>\r\n    <link href="https://img.youm7.com/images/graphics/favicon.ico" rel="shortcut icon" type="image/x-icon" />\r\n    <meta name="application-name" content="Youm7" />\r\n    <meta name="msapplication-starturl" content="https://www.youm7.com" />\r\n    <meta name="msapplication-tooltip" content="Youm7, the world\'s most wonderful site" />\r\n    <link href=\'/css/textfont/droidarabicnaskh.css\' rel=\'stylesheet\' type=\'text/css\'>\r\n    <link href=\'/css/textfont/droidarabickufi.css\' rel=\'stylesheet\' type=\'text/css\'>\r\n    <link href="https://maxcdn.bootstrapcdn.com/font-aw
# ...

# %% [markdown]
# ## Observation as shown prevously the output is the same as the data you saw before using Right click --> view source page.....try it to make sure

# %% [markdown]
# ## we need to filter out the data, therefore the data that need to be extracted include but not limited to :-
#
# ### 1-Title of the article in the website
# ### 2- The images of the article
# ### 3- the author of the title
# ### 4-  tags or Keywords of the article
# ### 5-  the article it selfs
#
# in order to take these kind of information we need to use another library called `BeautifulSoup`  in this [Link](https://www.crummy.com/software/BeautifulSoup/bs4/doc/) you can find full documentation about the library

# %%
#!pip install bs4
from bs4 import BeautifulSoup
import requests
import warnings
warnings.filterwarnings("ignore")

# %%
soup = BeautifulSoup(data)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <title>تداول المنتجات بالبورصة السلعية ينطلق بالربع الأول من 2022.. هدفها تقليل حلقات تسليم السلع لتخفيض الأسعار.. وعقد توأمة مع بورصة بيلاروسيا للاستفادة من خبراتها.. وحسن السمعة شرط قيد الشركات مع تشجيع صغار التجار - اليوم السابع</title>
# <meta content="charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=1190" name="viewport"/>
# <link href="https://img.youm7.com/images/graphics/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <meta content="Youm7" name="application-name"/>
# <meta content="https://www.youm7.com" name="msapplication-starturl"/>
# <meta content="Youm7, the world's most wonderful site" name="msapplication-tooltip"/>
# <link href="/css/textfont/droidarabicnaskh.css" rel="stylesheet" type="text/css"/>
# <link href="/css/textfont/droidarabickufi.css" rel="stylesheet" type="text/css"/>
# ...

# %% [markdown]
# ## lets get the title of the article

# %%
soup.title
# Out:
# <title>تداول المنتجات بالبورصة السلعية ينطلق بالربع الأول من 2022.. هدفها تقليل حلقات تسليم السلع لتخفيض الأسعار.. وعقد توأمة مع بورصة بيلاروسيا للاستفادة من خبراتها.. وحسن السمعة شرط قيد الشركات مع تشجيع صغار التجار - اليوم السابع</title>

# %% [markdown]
# ## Observation as shown previously the output inlcude the HTML content we need to extract the text only we make it using `text`

# %%
title = soup.title.text
title
# Out:
# 'تداول المنتجات بالبورصة السلعية ينطلق بالربع الأول من 2022.. هدفها تقليل حلقات تسليم السلع لتخفيض الأسعار.. وعقد توأمة مع بورصة بيلاروسيا للاستفادة من خبراتها.. وحسن السمعة شرط قيد الشركات مع تشجيع صغار التجار - اليوم السابع'

# %% [markdown]
# ## lets get the images
#
# ## to get the images in the article we can see there is more than one image, therefore i want to know the name object of that spesific image
#
#
# ### steps
#
# #### 1-Right Click inside the webpage
#
# #### 2-click on inspect
#
# ![<Spam step_1>](step_1.png)
#
#
# #### 3-as shown in the image you can see inspector mouse, click on it
#
#
#
#
# ![<Spam step_1>](step_2.png)
#
#
#
#
#
#
# #### 4-hover your mouse on the required image that you want to find its name, as you can see in the second image the image class

# %% [markdown]
# ### observation the image name is `img`.
# ### lets find the image with its name using `soup.find`

# %%
soup
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <title>تداول المنتجات بالبورصة السلعية ينطلق بالربع الأول من 2022.. هدفها تقليل حلقات تسليم السلع لتخفيض الأسعار.. وعقد توأمة مع بورصة بيلاروسيا للاستفادة من خبراتها.. وحسن السمعة شرط قيد الشركات مع تشجيع صغار التجار - اليوم السابع</title>
# <meta content="charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=1190" name="viewport"/>
# <link href="https://img.youm7.com/images/graphics/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <meta content="Youm7" name="application-name"/>
# <meta content="https://www.youm7.com" name="msapplication-starturl"/>
# <meta content="Youm7, the world's most wonderful site" name="msapplication-tooltip"/>
# <link href="/css/textfont/droidarabicnaskh.css" rel="stylesheet" type="text/css"/>
# <link href="/css/textfont/droidarabickufi.css" rel="stylesheet" type="text/css"/>
# ...

# %%
soup.find('img')
# Out:
# <img alt="" height="1" src="https://d5nxst8fruw4z.cloudfront.net/atrk.gif?account=Oo52f1a0mN00oV" style="display:none" width="1"/>

# %% [markdown]
# ### observation there is a link open it but as you can see the dimension of the image is 1 and 1 for hight and width respectly.
#
# ### i think this is not the image that we want
#
# ### `soup.find` returns the first outcome from the html file named image
#
# ### we need to be spesific about the name
#
# ### as you can see from the image below. above the img --> `<div class={img-cont}` lets search on it

# %% [markdown]
# ![<Spam step_1>](step_3.png)

# %%
soup.find('div',attrs={'class':'img-cont'})
# Out:
# <div class="img-cont">
# <img alt="تداول المنتجات بالبورصة السلعية ينطلق بالربع الأول من 2022.. هدفها تقليل حلقات تسليم السلع لتخفيض الأسعار.. وعقد توأمة مع بورصة بيلاروسيا للاستفادة من خبراتها.. وحسن السمعة شرط قيد الشركات مع تشجيع صغار التجار" class="img-responsive" data-src="https://img.youm7.com/large/202109021125392539.jpg" onerror="this.src='https://img.youm7.com/images/graphics/erorr-img-large.jpg'" src="https://img.youm7.com/large/202109021125392539.jpg" title="تداول المنتجات بالبورصة السلعية ينطلق بالربع الأول من 2022.. هدفها تقليل حلقات تسليم السلع لتخفيض الأسعار.. وعقد توأمة مع بورصة بيلاروسيا للاستفادة من خبراتها.. وحسن السمعة شرط قيد الشركات مع تشجيع صغار التجار"/>
# <span class="img-cap">تداول المنتجات بالبورصة السلعية فى الربع الأول من 2022 </span>
# </div>

# %%
# html = '<td valign="top">.....</td>\
#         <td width="580" valign="top">.......</td>\
#         <td>.....</td>'

html = '<td   valign="down"  </td>\
        <td width="580" valign="top">MMMMM</td>\
        <td>MMMMM</td>'
soup = BeautifulSoup(html)
results = soup.findAll("td")
results
# Out:
# [<td valign="down"> </td>,
#  <td valign="top" width="580">MMMMM</td>,
#  <td>MMMMM</td>]

# %% [markdown]
# ### `attrs` filter out the HTML data that includes the only attributes with the filtered keywords

# %%
results = soup.findAll("td", attrs={"valign" : "top"})

results
# Out:
# [<td valign="top" width="580">MMMMM</td>]

# %%
results = soup.findAll("td", attrs={"valign" : "down"})

results
# Out:
# [<td valign="down"> </td>]

# %% [markdown]
# ### observation he gets the whole class as shown prev. therefore we need to be more spesified, but inside this block.
#
# ### in order to make that we need to find the image named `img` only and neglect the other objects inside the block. we can perform this task using `.find()`

# %%
soup.find('div',attrs={'class':'img-cont'})
# Out:
# <div class="img-cont">
# <img alt="تداول المنتجات بالبورصة السلعية ينطلق بالربع الأول من 2022.. هدفها تقليل حلقات تسليم السلع لتخفيض الأسعار.. وعقد توأمة مع بورصة بيلاروسيا للاستفادة من خبراتها.. وحسن السمعة شرط قيد الشركات مع تشجيع صغار التجار" class="img-responsive" data-src="https://img.youm7.com/large/202109021125392539.jpg" onerror="this.src='https://img.youm7.com/images/graphics/erorr-img-large.jpg'" src="https://img.youm7.com/large/202109021125392539.jpg" title="تداول المنتجات بالبورصة السلعية ينطلق بالربع الأول من 2022.. هدفها تقليل حلقات تسليم السلع لتخفيض الأسعار.. وعقد توأمة مع بورصة بيلاروسيا للاستفادة من خبراتها.. وحسن السمعة شرط قيد الشركات مع تشجيع صغار التجار"/>
# <span class="img-cap">تداول المنتجات بالبورصة السلعية فى الربع الأول من 2022 </span>
# </div>

# %% [markdown]
# ### as shown in the prev output there is three more attrs we can spesific our search on them :-
#
# #### 1- `<img alt="` --> in the first line
#
# #### 2- `class="` --> in the third line
#
# #### 3- `data-src="` --> in the third line also
#
# #### 4- `onerror="` --> in the third line also
#
# #### 3- `src="` --> in the fifth line also
#
# #### 2- `title="` --> in the first line

# %%
soup.find('div',attrs={'class':'img-cont'}).find('img')
# Out:
# <img alt="تداول المنتجات بالبورصة السلعية ينطلق بالربع الأول من 2022.. هدفها تقليل حلقات تسليم السلع لتخفيض الأسعار.. وعقد توأمة مع بورصة بيلاروسيا للاستفادة من خبراتها.. وحسن السمعة شرط قيد الشركات مع تشجيع صغار التجار" class="img-responsive" data-src="https://img.youm7.com/large/202109021125392539.jpg" onerror="this.src='https://img.youm7.com/images/graphics/erorr-img-large.jpg'" src="https://img.youm7.com/large/202109021125392539.jpg" title="تداول المنتجات بالبورصة السلعية ينطلق بالربع الأول من 2022.. هدفها تقليل حلقات تسليم السلع لتخفيض الأسعار.. وعقد توأمة مع بورصة بيلاروسيا للاستفادة من خبراتها.. وحسن السمعة شرط قيد الشركات مع تشجيع صغار التجار"/>

# %% [markdown]
# ### the image is in src which is in the third line

# %%
soup.find('div',attrs={'class':'img-cont'}).find('img')['src']
# Out:
# 'https://img.youm7.com/large/202109021125392539.jpg'

# %% [markdown]
# ### open the prev link and trust me this is the image that we are looking for
#
# https://img.youm7.com/large/202109021125392539.jpg

# %%
image =soup.find('div',attrs={'class':'img-cont'}).find('img')['src']

# %% [markdown]
# ## we need to get the writer of the article
#
# ![<Spam step_1>](step_4.png)

# %%
soup.find('span')
# Out:
# <span class="date-header"><i aria-hidden="true" class="fa fa-calendar"></i> السبت، 04 ديسمبر 2021  <i aria-hidden="true" class="fa fa-clock-o"></i> 04:35 م </span>

# %%
soup.find('span',attrs={'class':'writeBy'})
# Out:
# <span class="writeBy">كتب مدحت وهبة</span>

# %%
soup.find('span',attrs={'class':'writeBy'}).text
# Out:
# 'كتب مدحت وهبة'

# %% [markdown]
# ## we need to delete the word 'كتب' or replace it or any method you want

# %%
soup.find('span',attrs={'class':'writeBy'}).text.replace('كتب','')
# Out:
# ' مدحت وهبة'

# %% [markdown]
# ## we have a space in the left how we can remove it...guess what we made it in the prev lecture--> using `strip()` or `lstrip()`

# %%
writer = soup.find('span',attrs={'class':'writeBy'}).text.replace('كتب','').strip()
writer
# Out:
# 'مدحت وهبة'

# %% [markdown]
# ## another method

# %%
writer=soup.find('span',attrs={'class':'writeBy'}).text

# %%
writer.split()
# Out:
# ['كتب', 'مدحت', 'وهبة']

# %% [markdown]
# ### i want to take the second and the third

# %%
writer.split()[1:]
# Out:
# ['مدحت', 'وهبة']

# %% [markdown]
# ### i want to join them again to be full name

# %%
' '.join(writer.split()[1:])
# Out:
# 'مدحت وهبة'

# %% [markdown]
# ### a third method using the length of the string

# %%
len(writer)
# Out:
# 13

# %%
writer
# Out:
# 'كتب مدحت وهبة'

# %%
writer.strip()
# Out:
# 'كتب مدحت وهبة'

# %%
writer[1:].strip()
# Out:
# 'تب مدحت وهبة'

# %%
writer[2:].strip()
# Out:
# 'ب مدحت وهبة'

# %%
writer[3:].strip()
# Out:
# 'مدحت وهبة'

# %%
writer.replace('كتب','').strip()
# Out:
# 'مدحت وهبة'

# %% [markdown]
# ## lets find the tags
#
# ![<Spam step_1>](step_5.png)

# %%
soup.find('div')
# Out:
# <div class="row marigin0 headerNewNew">
# <div class="header">
# <!--First Menu-->
# <div class="firstMenu">
# <div class="container-new-menu">
# <div class="fixedMenMen" style="position:relative;">
# <div class="container-navigation">
# <div>
# <!--<img src="https://www.youm7.com/images/newHeader/our-website.png" class="ourWebsites">-->
# <div class="flexslider">
# <div class="swiper-f">
# <div class="swiper-wrapper">
# <div class="swiper-slide">
# <a href="https://www.youm7.com/" target="_self">
# <img alt="اليوم السابع" class="img-responsive slider-img" src="https://img.youm7.com/ArticleImgs/2020/2/26/8847-youm7logofixed.png"/>
# </a>
# </div>
# <div class="swiper-slide">
# <a href="https://www.youm7.com/home/advert">
# <img alt="Ads" class="img-responsive slider-img" src="/images/newHeader/ad.png"/>
# </a>
# </div>
# </div>
# </div>
# </div>
# ...

# %% [markdown]
# ## the tags have a div and `class:tags` attrs

# %%
soup.find('div',attrs={'class':'tags'})
# Out:
# <div class="tags">
# <div class="tags">
# <img src="/images/tagNewNew.png?2"/>
# <h3>
# <a href="/Tags/Index?id=76135&amp;tag=البورصة-السلعية">البورصة السلعية  </a>
# </h3>
# <h3>
# <a href="/Tags/Index?id=2388818&amp;tag=بورصة-سلع-بيلاروسيا">بورصة سلع بيلاروسيا  </a>
# </h3>
# <h3>
# <a href="/Tags/Index?id=2080714&amp;tag=بورصة-السلع-المصرية">بورصة السلع المصرية  </a>
# </h3>
# <h3>
# <a href="/Tags/Index?id=15293&amp;tag=وزارة-التموين">وزارة التموين  </a>
# </h3>
# </div>
# </div>

# %% [markdown]
# ### using `find` we can filter out the output that have pattern `a`

# %%
soup.find('div',attrs={'class':'tags'}).find('a')
# Out:
# <a href="/Tags/Index?id=76135&amp;tag=البورصة-السلعية">البورصة السلعية  </a>

# %% [markdown]
# ### observations:- oopps we had the first output only, how we can find the others

# %% [markdown]
# ## we can see that the tags have another tiny thing we can make it using `findAll` method.
#
# why becuase you an returned output list, and we prev took that findAll can search in patterns, so we can search on the lines that includes `a`

# %%
soup.find('div',attrs={'class':'tags'}).findAll('a')
# Out:
# [<a href="/Tags/Index?id=76135&amp;tag=البورصة-السلعية">البورصة السلعية  </a>,
#  <a href="/Tags/Index?id=2388818&amp;tag=بورصة-سلع-بيلاروسيا">بورصة سلع بيلاروسيا  </a>,
#  <a href="/Tags/Index?id=2080714&amp;tag=بورصة-السلع-المصرية">بورصة السلع المصرية  </a>,
#  <a href="/Tags/Index?id=15293&amp;tag=وزارة-التموين">وزارة التموين  </a>]

# %% [markdown]
# ### the output returned in a list we need to fiter this out
#
# 1- we need to get each item in the list
#
# 2- we need to get the text in each item from the list

# %%
tags = []
for a in soup.find('div',attrs={'class':'tags'}).findAll('a'):
    tags.append(a.text.strip())
    
tags
# Out:
# ['البورصة السلعية',
#  'بورصة سلع بيلاروسيا',
#  'بورصة السلع المصرية',
#  'وزارة التموين']

# %%
','.join(tags)
# Out:
# 'البورصة السلعية,بورصة سلع بيلاروسيا,بورصة السلع المصرية,وزارة التموين'

# %% [markdown]
# ## or another method

# %%
tags = ''
for a in soup.find('div',attrs={'class':'tags'}).findAll('a'):
    tags += ','+a.text
    
tags
# Out:
# ',البورصة السلعية  ,بورصة سلع بيلاروسيا  ,بورصة السلع المصرية  ,وزارة التموين  '

# %% [markdown]
# ## we can find from the html source using `meta`
#
# but this is a easier way to make sure that google or other ads engins **take no time** to clean the data and get it directly to increase its possibilities finding

# %%
tags = soup.find('meta',attrs={'name':'keywords'})['content']
tags
# Out:
# 'البورصة السلعية,بورصة سلع بيلاروسيا,بورصة السلع المصرية,وزارة التموين'

# %% [markdown]
# ## The aticle can be found in `div` with attrs `id:articleBody`

# %%
article = soup.find('div',attrs={'id':'articleBody'})
article
# Out:
# <div id="articleBody">
# <div>
# ...

# %% [markdown]
# ## we need the text only from this result, therfore we will use `.text` method

# %%
article = soup.find('div',attrs={'id':'articleBody'}).text
article
# Out:
# '\n\r\n\tنجحت الحكومة\xa0 في تأسيس البورصة السلعية المصرية لتقليل حلقات تداول المنتجات والسلع بين الوسطاء بما يضمن انخفاض تكاليف النقل الأمر الذى سينعكس على السعر النهائي للمنتج ، حيث تهدف البورصة السلعية إلى تقليل حلقات تداول السلع بين المزارعين والمنتجين وصولا إلى يد المستهلك، ويستطيع البائع" مزارع أو تاجر أو منتج "إيداع السلع داخل المخازن المعتمدة من قبل وزارة التموين بعد تصنيفها وإعطاء درجة لجودتها ليتم تداولها مباشرة على المنصة الإلكترونية للبورصة التي تعرض الكميات المتاحة من كل سلعة على شاشات البورصة لتتحكم آليات وقوى العرض والطلب بين البائع والمشترى في تحديد سعر تلك السلع لصالح المستهلك مما سنعكس بشكل إيجابي على أسعار السلع والمنتجات ومن المقرر أن يبدا أول تدول للسع فى\xa0 البورصة السلعية اعتبارا من الربع الاول من عام 2022\xa0 .\n\r\n\t\xa0\n\r\n\tويأتى ذلك فى الوقت الذى أكد فيه\xa0 الدكتور على المصيلحى وزير التموين والتجارة الداخلية أن البورصة السلعية ستوفر قدراً من الحماية لصغار المزارعين والمنتجين عن طريق جمع إنتاجهم وتصنيفه، وإتاحته على كافة المتعاملين على منصة البورصة، في
# ...

# %%
article=str(article)
article
# Out:
# '\n\r\n\tنجحت الحكومة\xa0 في تأسيس البورصة السلعية المصرية لتقليل حلقات تداول المنتجات والسلع بين الوسطاء بما يضمن انخفاض تكاليف النقل الأمر الذى سينعكس على السعر النهائي للمنتج ، حيث تهدف البورصة السلعية إلى تقليل حلقات تداول السلع بين المزارعين والمنتجين وصولا إلى يد المستهلك، ويستطيع البائع" مزارع أو تاجر أو منتج "إيداع السلع داخل المخازن المعتمدة من قبل وزارة التموين بعد تصنيفها وإعطاء درجة لجودتها ليتم تداولها مباشرة على المنصة الإلكترونية للبورصة التي تعرض الكميات المتاحة من كل سلعة على شاشات البورصة لتتحكم آليات وقوى العرض والطلب بين البائع والمشترى في تحديد سعر تلك السلع لصالح المستهلك مما سنعكس بشكل إيجابي على أسعار السلع والمنتجات ومن المقرر أن يبدا أول تدول للسع فى\xa0 البورصة السلعية اعتبارا من الربع الاول من عام 2022\xa0 .\n\r\n\t\xa0\n\r\n\tويأتى ذلك فى الوقت الذى أكد فيه\xa0 الدكتور على المصيلحى وزير التموين والتجارة الداخلية أن البورصة السلعية ستوفر قدراً من الحماية لصغار المزارعين والمنتجين عن طريق جمع إنتاجهم وتصنيفه، وإتاحته على كافة المتعاملين على منصة البورصة، في
# ...

# %%
import re

# %% [markdown]
# ### we need to filter out the `\n` or `r` and so on

# %%
step_1=re.findall('[A-Za-zأ-ي0-9._,"]+',article)
step_1
# Out:
# ['نجحت',
#  'الحكومة',
#  'في',
#  'تأسيس',
#  'البورصة',
#  'السلعية',
#  'المصرية',
#  'لتقليل',
#  'حلقات',
#  'تداول',
#  'المنتجات',
#  'والسلع',
#  'بين',
#  'الوسطا',
#  'بما',
#  'يضمن',
#  'انخفاض',
#  'تكاليف',
#  'النقل',
#  'الأمر',
#  'الذى',
#  'سينعكس',
#  'على',
#  'السعر',
#  'النهائي',
#  'للمنتج',
#  'حيث',
#  'تهدف',
#  'البورصة',
#  'السلعية',
#  'إلى',
#  'تقليل',
#  'حلقات',
#  'تداول',
#  'السلع',
#  'بين',
#  'المزارعين',
#  'والمنتجين',
#  'وصولا',
#  'إلى',
#  'يد',
#  'المستهلك',
#  'ويستطيع',
#  'البائع"',
#  'مزارع',
#  'أو',
#  'تاجر',
#  'أو',
#  'منتج',
#  '"إيداع',
#  'السلع',
#  'داخل',
#  'المخازن',
#  'المعتمدة',
#  'من',
#  'قبل',
#  'وزارة',
#  'التموين',
#  'بعد',
#  'تصنيفها',
#  'وإعطا',
#  'درجة',
#  'لجودتها',
#  'ليتم',
#  'تداولها',
#  'مباشرة',
#  'على',
#  'المنصة',
#  'الإلكترونية',
#  'للبورصة',
#  'التي',
#  'تعرض',
#  'الكميات',
#  'المتاحة',
#  'من',
#  'كل',
#  'سلعة',
#  'على',
#  'شاشات',
#  'البورصة',
#  'لتتحكم',
#  'ليات',
# ...

# %%
(' ').join(step_1)
# Out:
# 'نجحت الحكومة في تأسيس البورصة السلعية المصرية لتقليل حلقات تداول المنتجات والسلع بين الوسطا بما يضمن انخفاض تكاليف النقل الأمر الذى سينعكس على السعر النهائي للمنتج حيث تهدف البورصة السلعية إلى تقليل حلقات تداول السلع بين المزارعين والمنتجين وصولا إلى يد المستهلك ويستطيع البائع" مزارع أو تاجر أو منتج "إيداع السلع داخل المخازن المعتمدة من قبل وزارة التموين بعد تصنيفها وإعطا درجة لجودتها ليتم تداولها مباشرة على المنصة الإلكترونية للبورصة التي تعرض الكميات المتاحة من كل سلعة على شاشات البورصة لتتحكم ليات وقوى العرض والطلب بين البائع والمشترى في تحديد سعر تلك السلع لصالح المستهلك مما سنعكس بشكل إيجابي على أسعار السلع والمنتجات ومن المقرر أن يبدا أول تدول للسع فى البورصة السلعية اعتبارا من الربع الاول من عام 2022 . ويأتى ذلك فى الوقت الذى أكد فيه الدكتور على المصيلحى وزير التموين والتجارة الداخلية أن البورصة السلعية ستوفر قدرا من الحماية لصغار المزارعين والمنتجين عن طريق جمع إنتاجهم وتصنيفه وإتاحته على كافة المتعاملين على منصة البورصة في شكل سوق منظم على النحو الذى يساهم فى زيادة القدرة ا
# ...

# %%
another_method=re.findall('[\w\._,"]+',article)
another_method
(' ').join(another_method)
# Out:
# 'نجحت الحكومة في تأسيس البورصة السلعية المصرية لتقليل حلقات تداول المنتجات والسلع بين الوسطاء بما يضمن انخفاض تكاليف النقل الأمر الذى سينعكس على السعر النهائي للمنتج حيث تهدف البورصة السلعية إلى تقليل حلقات تداول السلع بين المزارعين والمنتجين وصولا إلى يد المستهلك ويستطيع البائع" مزارع أو تاجر أو منتج "إيداع السلع داخل المخازن المعتمدة من قبل وزارة التموين بعد تصنيفها وإعطاء درجة لجودتها ليتم تداولها مباشرة على المنصة الإلكترونية للبورصة التي تعرض الكميات المتاحة من كل سلعة على شاشات البورصة لتتحكم آليات وقوى العرض والطلب بين البائع والمشترى في تحديد سعر تلك السلع لصالح المستهلك مما سنعكس بشكل إيجابي على أسعار السلع والمنتجات ومن المقرر أن يبدا أول تدول للسع فى البورصة السلعية اعتبارا من الربع الاول من عام 2022 . ويأتى ذلك فى الوقت الذى أكد فيه الدكتور على المصيلحى وزير التموين والتجارة الداخلية أن البورصة السلعية ستوفر قدرا من الحماية لصغار المزارعين والمنتجين عن طريق جمع إنتاجهم وتصنيفه وإتاحته على كافة المتعاملين على منصة البورصة في شكل سوق منظم على النحو الذى يساهم فى زيادة القدر
# ...

# %% [markdown]
# ## or another method

# %%
third_method=article.replace('\n','').replace('\t','').replace('\r','').replace('\xa0','').replace('\u200f','')
third_method
# Out:
# 'نجحت الحكومة في تأسيس البورصة السلعية المصرية لتقليل حلقات تداول المنتجات والسلع بين الوسطاء بما يضمن انخفاض تكاليف النقل الأمر الذى سينعكس على السعر النهائي للمنتج ، حيث تهدف البورصة السلعية إلى تقليل حلقات تداول السلع بين المزارعين والمنتجين وصولا إلى يد المستهلك، ويستطيع البائع" مزارع أو تاجر أو منتج "إيداع السلع داخل المخازن المعتمدة من قبل وزارة التموين بعد تصنيفها وإعطاء درجة لجودتها ليتم تداولها مباشرة على المنصة الإلكترونية للبورصة التي تعرض الكميات المتاحة من كل سلعة على شاشات البورصة لتتحكم آليات وقوى العرض والطلب بين البائع والمشترى في تحديد سعر تلك السلع لصالح المستهلك مما سنعكس بشكل إيجابي على أسعار السلع والمنتجات ومن المقرر أن يبدا أول تدول للسع فى البورصة السلعية اعتبارا من الربع الاول من عام 2022 .ويأتى ذلك فى الوقت الذى أكد فيه الدكتور على المصيلحى وزير التموين والتجارة الداخلية أن البورصة السلعية ستوفر قدراً من الحماية لصغار المزارعين والمنتجين عن طريق جمع إنتاجهم وتصنيفه، وإتاحته على كافة المتعاملين على منصة البورصة، في شكل سوق منظم على النحو الذى يساهم فى زيادة 
# ...

# %%
def get_article_details(url):
    data    = requests.get(url).text
    soup    = BeautifulSoup(data)    
    title   = soup.title.text
    image   = soup.find('div',attrs={'class':'img-cont'}).find('img')['src']
    writer  = soup.find('span',attrs={'class':'writeBy'}).text.replace('كتبت','').replace('كتب','').strip()
    tags    = soup.find('meta',attrs={'name':'keywords'})['content']
    article = soup.find('div',attrs={'id':'articleBody'}).text
    article=re.findall('[\w\._,"]+',article)
    article=(' ').join(article)
#     article = article.replace('\n','').replace('\t','').replace('\r','').replace('\xa0','').replace('\u200f','')
    return {'url':url,
            'title':title,
            'image':image,
            'writer':writer,
            'tags':tags,
            'article':article}

# %%
get_article_details('https://www.youm7.com/story/2021/4/12/7-%D8%B3%D9%86%D9%88%D8%A7%D8%AA-%D9%85%D9%86-%D8%A7%D9%84%D9%85%D9%83%D8%A7%D8%B3%D8%A8-%D8%A7%D9%84%D8%B5%D9%86%D8%A7%D8%B9%D9%8A%D8%A9-%D9%81%D9%89-%D8%B9%D9%87%D8%AF-%D8%A7%D9%84%D8%B1%D8%A6%D9%8A%D8%B3-%D8%A7%D9%84%D8%B3%D9%8A%D8%B3%D9%89-%D8%A7%D8%B3%D8%AA%D8%B1%D8%A7%D8%AA%D9%8A%D8%AC%D9%8A%D8%A9/5278253')
# Out:
# {'article': 'تتبنى الدولة خططًا طموحة من أجل دعم الصناعة الوطنية، وذلك عن طريق تدشين 4317 مصنعا بالقطاعات الصناعية المختلفة موزعة بين محافظات الجمهورية، تراعي الميزة النسبية التي تشتهر بها كل محافظة من المحافظات.وشهدت الفترة الماضية، تدشين أكبر مدينة لصناعة الأثاث في دمياط بمساحة تتخطي 330 فدانا تضم أحد أهم القطاعات الاقتصادية في مصر، وتلبي احتياجات السوق المحلية وتوجيه الانتاج للتصدير، كما يجري تدشين مدينة للنسيج في السادات بالمنوفية والتي تقام على مساحة 3.1 مليون متر باستثمارات مصرية وشراكة صينية.وتم الانتهاء من تشغيل مدينة الروبيكى للجلود على مساحة 160 فدانا، وبدء المرحلة الثانية بدمياط، ومدينتين للنسيج فى بدر، إلى جانب المجمعات الصناعية الصغيرة فى مدن السادات وجنوب الرسوة وغيرها، وذلك للحد من الاستيراد العشوائى، وفتح الطريق أمام الصناعة الوطنية، ليصل إجمالي المصانع الصغيرة التي يجرى تدشينها أكثر من 4 آلاف مصنع.وخلال هذا الأسبوع تم توقيع العقود النهائية وتسليم الوحدات الصناعية الجاهزة للمستثمرين بالـ 7 مجمعات صناعية والتي تم طرحها بـ 7 محافظات تشمل الغربية والإسكندرية وبني سويف وا
# ...

# %%
data = requests.get('https://www.youm7.com/Section/%D8%A3%D8%AE%D8%A8%D8%A7%D8%B1-%D8%A7%D9%84%D8%B1%D9%8A%D8%A7%D8%B6%D8%A9/298/2').text

# %%
soup = BeautifulSoup(data)
soup.title
# Out:
# <title>تداول المنتجات بالبورصة السلعية ينطلق بالربع الأول من 2022.. هدفها تقليل حلقات تسليم السلع لتخفيض الأسعار.. وعقد توأمة مع بورصة بيلاروسيا للاستفادة من خبراتها.. وحسن السمعة شرط قيد الشركات مع تشجيع صغار التجار - اليوم السابع</title>

# %% [markdown]
# ## in the source code html the overall container for all the classes that hs prev done such as the article, the author, images and so on.. are inside an
#
# # `<div id='paging'>`

# %% [markdown]
# ![image.png](step_6.png)

# %% [markdown]
# ![image.png](step_7.png)

# %%
data  = requests.get('https://www.youm7.com/Section/%D8%A3%D8%AE%D8%A8%D8%A7%D8%B1-%D8%A7%D9%84%D8%B1%D9%8A%D8%A7%D8%B6%D8%A9/298/1').text    
data
# Out:
# '<!DOCTYPE html>\r\n<html>\r\n<head>\r\n    <title>أخبار الرياضة - اليوم السابع</title>\r\n    <meta http-equiv="Content-Type" content="charset=utf-8" />\r\n    <meta name=\'viewport\' content=\'width=1190\'>\r\n    <link href="https://img.youm7.com/images/graphics/favicon.ico" rel="shortcut icon" type="image/x-icon" />\r\n    <meta name="application-name" content="Youm7" />\r\n    <meta name="msapplication-starturl" content="https://www.youm7.com" />\r\n    <meta name="msapplication-tooltip" content="Youm7, the world\'s most wonderful site" />\r\n    <link href=\'/css/textfont/droidarabicnaskh.css\' rel=\'stylesheet\' type=\'text/css\'>\r\n    <link href=\'/css/textfont/droidarabickufi.css\' rel=\'stylesheet\' type=\'text/css\'>\r\n    <link href="https://maxcdn.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css" rel="stylesheet" integrity="sha384-wvfXpqpZZVQGK6TAh5PVlGOfQNHSoD2xbE+QkPxCAFlNEevoEH3Sl0sibVcOQVnN" crossorigin="anonymous">\r\n    <meta property="og:image" con
# ...

# %%
soup  = BeautifulSoup(data)
links = []
soup.find('div',attrs={'id':'paging'})
# Out:
# <div id="paging">
# <div class="col-xs-12 bigOneSec" data-id="12/4/2021 10:25:19 PM">
# <a class="bigOneImg" href="/story/2021/12/4/الجماهير-لا-منتصر-ولا-خاسر-مصر-والسودان-واحد/5565616">
# <img alt="الجماهير: لا منتصر ولا خاسر مصر والسودان واحد" class="img-responsive" onerror="this.src='https://img.youm7.com/images/graphics/erorr-img-med.jpg'" src="https://img.youm7.com/medium/202112040922102210.jpg" title="الجماهير: لا منتصر ولا خاسر مصر والسودان واحد"/>
# </a>
# <div>
# <h3>
# <a href="/story/2021/12/4/الجماهير-لا-منتصر-ولا-خاسر-مصر-والسودان-واحد/5565616">
#                                                             الجماهير: لا منتصر ولا خاسر مصر والسودان واحد
#                                                         </a>
# </h3>
# <span class="newsDate2"> السبت، 04 ديسمبر 2021 10:25 م</span>
# <p>رفع المشجعون في مدرجات استاد 974 بالدوحة لافتة مكتوبة عليها "لا منتصر ولا خاسر مصر والسودان واحد" في لقطة تعكس مدى الحب والروح الرياضية التي تجمع جمهور الفريقين..</p>
# </div>
# </div>
# ...

# %%
soup.find('div',attrs={'id':'paging'}).findAll('a')
# Out:
# [<a class="bigOneImg" href="/story/2021/12/4/الجماهير-لا-منتصر-ولا-خاسر-مصر-والسودان-واحد/5565616">
#  <img alt="الجماهير: لا منتصر ولا خاسر مصر والسودان واحد" class="img-responsive" onerror="this.src='https://img.youm7.com/images/graphics/erorr-img-med.jpg'" src="https://img.youm7.com/medium/202112040922102210.jpg" title="الجماهير: لا منتصر ولا خاسر مصر والسودان واحد"/>
#  </a>,
#  <a href="/story/2021/12/4/الجماهير-لا-منتصر-ولا-خاسر-مصر-والسودان-واحد/5565616">
#                                                              الجماهير: لا منتصر ولا خاسر مصر والسودان واحد
#                                                          </a>,
#  <a class="bigOneImg" href="/story/2021/12/4/السودان-وش-السعد-على-4-لاعبين-في-منتخب-مصر-3/5565566">
# ...

# %%
soup.find('div',attrs={'id':'paging'}).findAll('a')['href']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-210-f956abf7bd4b> in <module>()
# ----> 1 soup.find('div',attrs={'id':'paging'}).findAll('a')['href']
#
# TypeError: list indices must be integers or slices, not str

# %%
# data  = requests.get('https://www.youm7.com/Section/%D8%A3%D8%AE%D8%A8%D8%A7%D8%B1-%D8%A7%D9%84%D8%B1%D9%8A%D8%A7%D8%B6%D8%A9/298/1'+str(1)+'').text    
data  = requests.get('https://www.youm7.com/Section/%D8%A3%D8%AE%D8%A8%D8%A7%D8%B1-%D8%A7%D9%84%D8%B1%D9%8A%D8%A7%D8%B6%D8%A9/298/1').text    
soup  = BeautifulSoup(data)
links = []
for a in soup.find('div',attrs={'id':'paging'}).findAll('a'):
    print(a['href'])
    links.append(a['href'])
# Out:
# /story/2021/12/4/الجماهير-لا-منتصر-ولا-خاسر-مصر-والسودان-واحد/5565616
# /story/2021/12/4/الجماهير-لا-منتصر-ولا-خاسر-مصر-والسودان-واحد/5565616
# /story/2021/12/4/السودان-وش-السعد-على-4-لاعبين-في-منتخب-مصر-3/5565566
# /story/2021/12/4/السودان-وش-السعد-على-4-لاعبين-في-منتخب-مصر-3/5565566
# /story/2021/12/4/أحمد-زيزو-بعد-هدفه-الدولى-الأول-وفوز-الفراعنة-على-السودان/5565642
# /story/2021/12/4/أحمد-زيزو-بعد-هدفه-الدولى-الأول-وفوز-الفراعنة-على-السودان/5565642
# /story/2021/12/4/عادل-عقل-لتليفزيون-اليوم-السابع-الـVAR-وكاريزما-كونجير-سر-نجاح/5565620
# /story/2021/12/4/عادل-عقل-لتليفزيون-اليوم-السابع-الـVAR-وكاريزما-كونجير-سر-نجاح/5565620
# /story/2021/12/4/باسم-مرسى-يعود-لتدريبات-سيراميكا-استعدادا-لمباراة-الاتحاد-السكندري-صور/5565626
# /story/2021/12/4/باسم-مرسى-يعود-لتدريبات-سيراميكا-استعدادا-لمباراة-الاتحاد-السكندري-صور/5565626
# /story/2021/12/4/هانى-رمزى-تشكيل-كيروش-نجح-بنسبة-100-أمام-السودان/5565639
# /story/2021/12/4/هانى-رمزى-تشكيل-كيروش-نجح-بنسبة-100-أمام-السودان/5565639
# ...

# %%
links
# Out:
# ['/story/2021/12/4/الجماهير-لا-منتصر-ولا-خاسر-مصر-والسودان-واحد/5565616',
#  '/story/2021/12/4/الجماهير-لا-منتصر-ولا-خاسر-مصر-والسودان-واحد/5565616',
#  '/story/2021/12/4/السودان-وش-السعد-على-4-لاعبين-في-منتخب-مصر-3/5565566',
#  '/story/2021/12/4/السودان-وش-السعد-على-4-لاعبين-في-منتخب-مصر-3/5565566',
#  '/story/2021/12/4/أحمد-زيزو-بعد-هدفه-الدولى-الأول-وفوز-الفراعنة-على-السودان/5565642',
#  '/story/2021/12/4/أحمد-زيزو-بعد-هدفه-الدولى-الأول-وفوز-الفراعنة-على-السودان/5565642',
#  '/story/2021/12/4/عادل-عقل-لتليفزيون-اليوم-السابع-الـVAR-وكاريزما-كونجير-سر-نجاح/5565620',
#  '/story/2021/12/4/عادل-عقل-لتليفزيون-اليوم-السابع-الـVAR-وكاريزما-كونجير-سر-نجاح/5565620',
#  '/story/2021/12/4/باسم-مرسى-يعود-لتدريبات-سيراميكا-استعدادا-لمباراة-الاتحاد-السكندري-صور/5565626',
#  '/story/2021/12/4/باسم-مرسى-يعود-لتدريبات-سيراميكا-استعدادا-لمباراة-الاتحاد-السكندري-صور/5565626',
#  '/story/2021/12/4/هانى-رمزى-تشكيل-كيروش-نجح-بنسبة-100-أمام-السودان/5565639',
# ...

# %%
type(links)
# Out:
# list

# %% [markdown]
# ### we need to remove the duplicated links, using `set()` in python

# %%
data  = requests.get('https://www.youm7.com/Section/%D8%A3%D8%AE%D8%A8%D8%A7%D8%B1-%D8%A7%D9%84%D8%B1%D9%8A%D8%A7%D8%B6%D8%A9/298/1').text    
soup  = BeautifulSoup(data)
links = []
for a in soup.find('div',attrs={'id':'paging'}).findAll('a'):
    links.append(a['href'])
list(set(links))
# Out:
# ['/story/2021/12/4/الزى-الفرعونى-وعلم-مصر-يزينان-مباراة-المنتخب-أمام-السودان-صور/5565451',
#  '/story/2021/12/4/تقسيمة-قوية-للاعبى-الزمالك-بمشاركة-رزاق-سيسيه-وفقرة-خاصة-للتسديد/5565378',
#  '/story/2021/12/4/أشرف-خضر-الإسماعيلى-يحتاج-لتدعيم-هجومى-وبصمات-بروان-ستظهر-بعد/5565188',
#  '/story/2021/12/4/مصر-والسودان-ثلاثية-نظيفة-للفراعنة-فى-شوط-أول-تاريخى-صور/5565412',
#  '/story/2021/12/4/9-لاعبين-×-7-مواجهات-كيروش-يواصل-الدفع-بالوجوه-الجديدة/5565390',
#  '/story/2021/12/4/جمال-حمزة-حظى-وحش-فى-الاحتراف-وأزمتى-مع-المعلم-بسبب/5565235',
#  '/story/2021/12/4/منتخب-مصر-يضرب-السودان-3-0-بعد-32-دقيقة-فيديو/5565411',
#  '/story/2021/12/4/انتظام-أبو-جبل-وعواد-وأوباما-فى-تدريبات-الزمالك-وراحة-لحامد/5565319',
#  '/story/2021/12/4/جمال-حمزة-الحمد-لله-إنى-ما-خلفتش-ولد-وتوهت-محمود/5565236',
#  '/story/2021/12/4/منتخب-مصر-يتوجه-إلى-ملعب-مباراة-السودان-قبل-اللقاء-بساعتين/5565062',
#  '/story/2021/12/4/كل-ما-تريد-معرفته-عن-مباراة-مصر-والسودان-اليوم-فى/5564675',
# ...

# %% [markdown]
# ## we can see that the links need to be completed with the first part of the link which is --> `https://youm7.com` so we need to add it

# %%
data  = requests.get('https://www.youm7.com/Section/%D8%A3%D8%AE%D8%A8%D8%A7%D8%B1-%D8%A7%D9%84%D8%B1%D9%8A%D8%A7%D8%B6%D8%A9/298/1').text    
soup  = BeautifulSoup(data)
links = []
for a in soup.find('div',attrs={'id':'paging'}).findAll('a'):
    links.append('https://youm7.com'+a['href'])
list(set(links))
# Out:
# ['https://youm7.com/story/2021/12/4/تونس-تستضيف-بطولة-أفريقيا-للأندية-أبطال-الدورى-لليد-والنيجر-للكؤوس/5565241',
#  'https://youm7.com/story/2021/12/4/حصاد-2021-5-دمعات-حزينة-للكرة-المصرية-أحدهم-لم-يتحمل/5563954',
#  'https://youm7.com/story/2021/12/4/تغييرات-بالجملة-زيزو-ورفعت-وحسين-فيصل-يقودون-منتخب-مصر-أمام/5565010',
#  'https://youm7.com/story/2021/12/4/انطلاق-معسكر-المنتخب-الأولمبي-غدا/5565232',
#  'https://youm7.com/story/2021/12/4/صرف-مستحقات-نوفمبر-للحكام-الاثنين-المقبل/5565238',
#  'https://youm7.com/story/2021/12/4/انتظام-أبو-جبل-وعواد-وأوباما-فى-تدريبات-الزمالك-وراحة-لحامد/5565319',
#  'https://youm7.com/story/2021/12/4/لاعبتا-الأهلي-تحققان-الميدالية-الذهبية-فى-بطولة-أفريقيا-للكاراتيه/5565495',
#  'https://youm7.com/story/2021/12/4/كل-ما-تريد-معرفته-عن-مباراة-مصر-والسودان-اليوم-فى/5564675',
#  'https://youm7.com/story/2021/12/4/منتخب-مصر-يضرب-السودان-3-0-بعد-32-دقيقة-فيديو/5565411',
# ...

# %% [markdown]
# ## now the links are completed

# %% [markdown]
# ![image.png](step_8.png)
# ![image.png](step_9.png)

# %% [markdown]
# ## lets make a function that takes the page number and gets all the data from the articles in each link

# %% [markdown]
# ### the only change as follows :-
# #### `Link`+`+str(page_no)+`+``

# %%
def get_links_from_page(page_no):
    data  = requests.get('https://www.youm7.com/Section/%D8%A3%D8%AE%D8%A8%D8%A7%D8%B1-%D8%A7%D9%84%D8%B1%D9%8A%D8%A7%D8%B6%D8%A9/298/1'+str(page_no)+'').text    
    soup  = BeautifulSoup(data)
    links = []
    for a in soup.find('div',attrs={'id':'paging'}).findAll('a'):
        links.append('https://youm7.com'+a['href'])
    return list(set(links))

# %%
links = get_links_from_page(3)

# %%
import pandas as pd
df = pd.DataFrame()
for link in links:
    new_df = pd.DataFrame(get_article_details(link),index=[0])
    df     = pd.concat([df,new_df],ignore_index=True)

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://youm7.com/story/2021/11/30/إيهاب-جلال-...
# 1  https://youm7.com/story/2021/11/30/الأهلي-يفوض...
# 2  https://youm7.com/story/2021/11/30/فخر-الدين-ب...
# 3  https://youm7.com/story/2021/11/30/الكاراتيه-ي...
# 4  https://youm7.com/story/2021/11/30/الألمانى-دا...
#
#                                                title  \
# 0  إيهاب جلال يمنح مهاجمى بيراميدز درس خصوصى قبل ...
# 1  الأهلي يفوض فهمي ومرتجي لحل أزمة مونديال الأند...
# 2  فخر الدين بن يوسف يحتفل بخماسية تونس بصحبة الج...
# 3  الكاراتيه يعلن شعار البطولة الأفريقية بالقاهرة...
# 4  الألمانى دانيال سيبرت " حكما " لمباراة مصر ولب...
#
#                                                image          writer  \
# 0  https://img.youm7.com/large/202111271113331333...       أحمد طارق
# 1  https://img.youm7.com/large/201907130450375037...  : سليمان النقر
# 2  https://img.youm7.com/large/20211130040024024.jpg       أسماء عمر
# ...

# %%
df.to_excel('articles.xlsx',index=False,encoding='utf-8')

# %%
links = get_links_from_page(1)
import pandas as pd
df = pd.DataFrame()
for link in links:
    new_df = pd.DataFrame(get_article_details(link),index=[0])
    df     = pd.concat([df,new_df],ignore_index=True)
df.head()
# Out:
#                                                  url  \
# 0  https://youm7.com/story/2021/12/1/التشكيل-المت...
# 1  https://youm7.com/story/2021/12/1/تعرف-على-رسا...
# 2  https://youm7.com/story/2021/12/1/كاف-يحتفل-بع...
# 3  https://youm7.com/story/2021/12/1/كارتيرون-يؤك...
# 4  https://youm7.com/story/2021/12/1/عيد-ميلاد-سع...
#
#                                                title  \
# 0  التشكيل المتوقع لمنتخب مصر ولبنان .. أحمد ياسي...
# 1  تعرف على رسالة موسيمانى للفراعنة قبل مواجهة لب...
# 2  كاف يحتفل بعيد ميلاد وليد سليمان: "مهارة من نو...
# 3  كارتيرون يؤكد للزمالك وصوله القاهرة الخميس - ا...
# 4  "عيد ميلاد سعيد يا حاوي" .. الأهلي يحتفل بعيد ...
#
#                                                image  \
# 0  https://img.youm7.com/large/202111291211151115...
# 1  https://img.youm7.com/large/202111201130313031...
# 2  https://img.youm7.com/large/202110090555215521...
# 3  https://img.youm7.com/large/202110160436163616...
# ...

# %%
df.to_excel('articles_page_1.xlsx',index=False,encoding='utf-8')

# %%
import pandas as pd
df = pd.DataFrame()
for i in range(1,10):
    for link in get_links_from_page(i):
        new_df = pd.DataFrame(get_article_details(link),index=[0])
        df     = pd.concat([df,new_df],ignore_index=True)
df.shape
# Out:
# (360, 6)

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://youm7.com/story/2021/9/3/قصة-صور-بيرسي...
# 1  https://youm7.com/story/2021/9/3/شيكابالا-يُفج...
# 2  https://youm7.com/story/2021/9/3/حارس-يد-الأهل...
# 3  https://youm7.com/story/2021/9/3/سلمى-على-تخسر...
# 4  https://youm7.com/story/2021/9/3/الغندور-يعلن-...
#
#                                                title  \
# 0  قصة صور.. بيرسي تاو اللاعب الذى تحدى المنطق وا...
# 1  شيكابالا يُفجر مفاجأة: أيمن حفنى هو من كان سيت...
# 2  حارس يد الأهلى: حققنا كأس الكؤوس الأفريقية عن...
# 3  سلمى على تخسر من بطلة العالم فى الباراتايكوندو...
# 4  الغندور يعلن قيمة انتقال بامبو من الزمالك للبن...
#
#                                                image          writer  \
# 0  https://img.youm7.com/large/20210902045001501.jpg     ت أسماء عمر
# 1  https://img.youm7.com/large/202108281029342934...   عمرو جاب الله
# 2  https://img.youm7.com/large/20210903014204424.jpg  محمد تهامى زكى
# ...

# %%
df.to_excel('articles.xlsx',index=False,encoding='utf-8')

# %%
import pandas as pd
#!pip install bs4
from bs4 import BeautifulSoup
import warnings
import requests
import warnings
warnings.filterwarnings("ignore")

data = requests.get('http://goldpricez.com/eg/gram').text
soup = BeautifulSoup(data)
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="Welcome to the gold price in Egypt, and today's gold price is 900.65 Egyptian Pound per Gram. We are also providing different charts of gold in Egyptian Pound" name="description"/>
# <meta content=" gram gold rates in Egypt,  gold price in Egyptian Pound,       gold price per gram in EGP, today gram gold rate in Egypt , 22k 21k 24k 20k 18k 14k gold price in  Egyptian Pound in Egypt, 1gram, 5gram, 10gram, 50gram" name="Keywords"/>
# <link href="http://goldpricez.com/assets/favicon.ico" rel="icon" type="image/x-icon"/>
# <link href="http://goldpricez.com/assets/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="http://goldpricez.com/assets/apple-touch-icon60.png" rel="apple-touch-icon"/>
# <link href="http://goldpricez.com/assets/apple-touch-icon76.png" rel="apple-touch-icon" sizes="76x76"/>
# ...

# %%
    	               
    	                   	                         
    	                           <h3 class="h3_background" itemprop="about">This Year (i.e, in 2021)  Gold Rates  </h3>
    	                         
    	                         <table id="historymain_table_gold1" class="tb">   <tbody><tr>         <th>Date</th><th>Gold Price in Egyptian Pound</th>   </tr>   <tr>         <td class="header2_center ">Today  </td><td class="header2_center ">900.65  EGP</td>   </tr>   <tr>         <td class="header2_center ">Yesterday  </td><td class="header2_center ">900.81  EGP</td>   </tr>   <tr>         <td class="header2_center ">Fri, 3rd Dec  </td><td class="header2_center ">902.13  EGP</td>   </tr>   <tr>         <td class="header2_center ">Thu, 2nd Dec  </td><td class="header2_center ">893.42  EGP</td>   </tr>   <tr>         <td class="header2_center ">Wed, 1st Dec  </td><td class="header2_center ">899.30  EGP</td>   </tr>   <tr>         <td class="header2_center ">Tue, 30th Nov  </td><td class="header2_center ">898.78  EGP</td>   </tr>   <tr>         <td class="header2_center ">Mon, 29th Nov  </td><td class="header2_center ">901.57  EGP</td>   </tr>   <tr>         <td class="header2_center ">Sun, 28th Nov  </td><td class="header2_center ">906.30  EGP</td>   </tr>   <tr>         <td class="header2_center ">Sat, 27th Nov  </td><td class="header2_center ">906.30  EGP</td>   </tr>   <tr>         <td class="header2_center ">Fri, 26th Nov  </td><td class="header2_center ">906.44  EGP</td>   </tr>   <tr>         <td class="header2_center ">Thu, 25th Nov  </td><td class="header2_center ">904.28  EGP</td>   </tr>   <tr>         <td class="header2_center ">Wed, 24th Nov  </td><td class="header2_center ">902.40  EGP</td>   </tr>   <tr>         <td class="header2_center ">Tue, 23rd Nov  </td><td class="header2_center ">903.48  EGP</td>   </tr>   <tr>         <td class="header2_center ">Mon, 22nd Nov  </td><td class="header2_center ">911.74  EGP</td>   </tr> </tbody></table>

# %%
soup.title
# Out:
# <title> Gold Price in Egypt - Today Gold Rate per Gram in EGP (Pound)  </title>

# %%
soup.find('div',attrs={'class':'col c5'}).text
# Out:
# '\nToday   Gold Prices   in Egypt\n  Gold UnitGold Rate in Egyptian Pound   Gram 24K 900.65  EGP   Gram 23K 863.13  EGP   Gram 22K 825.60  EGP   Gram 21K 788.07  EGP   Gram 18K 675.49  EGP   Gram 16K 600.44  EGP   Gram 14K 525.38  EGP   Gram 12K 450.33  EGP   Gram 10K 375.27  EGP   Gram 9K 337.75  EGP   Gram 8K 300.22  EGP   Gram 6K 225.16  EGP  \n'

# %%
soup.find('div',attrs={'class':'col c6 ccenter'})
# Out:
# <div class="col c6 ccenter" id="price-list-sizes">
# <h3 class="h3_background">   Gold Price in Different Quantities </h3>
# <table class="tb">
# <tr><th>Units of  Gold</th><th>Price in EGP</th></tr>
# <tr><td class="header2_center ">1    Gram Gold Price </td><td>  900.65 EGP </td></tr>
# <tr><td class="header2_center ">  5 Gram Gold Price </td><td> 4503.27 EGP  </td></tr>
# <tr><td class="header2_center "> 10 Gram Gold Price </td><td> 9006.54 EGP  </td></tr>
# <tr><td class="header2_center ">  20 Gram Gold Price </td><td> 18013.09 EGP </td></tr>
# <tr><td class="header2_center ">  40 Gram Gold Price </td><td> 36026.17 EGP </td></tr>
# <tr><td class="header2_center ">  50 Gram Gold Price </td><td> 45032.72 EGP </td></tr>
# <tr><td class="header2_center ">  100 Gram Gold Price </td><td> 90065.43 EGP </td></tr>
# <tr><td class="header2_center ">  1000 Gram Gold Price </td><td> 900654.3 EGP </td></tr>
# </table>
# </div>

# %%
tds = soup.find('div',attrs={'class':'col c6 ccenter'}).find('table').findAll('td')
tds
# Out:
# [<td class="header2_center ">1    Gram Gold Price </td>,
#  <td>  900.65 EGP </td>,
#  <td class="header2_center ">  5 Gram Gold Price </td>,
#  <td> 4503.27 EGP  </td>,
#  <td class="header2_center "> 10 Gram Gold Price </td>,
#  <td> 9006.54 EGP  </td>,
#  <td class="header2_center ">  20 Gram Gold Price </td>,
#  <td> 18013.09 EGP </td>,
#  <td class="header2_center ">  40 Gram Gold Price </td>,
#  <td> 36026.17 EGP </td>,
#  <td class="header2_center ">  50 Gram Gold Price </td>,
#  <td> 45032.72 EGP </td>,
#  <td class="header2_center ">  100 Gram Gold Price </td>,
#  <td> 90065.43 EGP </td>,
#  <td class="header2_center ">  1000 Gram Gold Price </td>,
#  <td> 900654.3 EGP </td>]

# %%
i = 1
prices = []
quantities = []
for td in tds:
    if i % 2==0:
        prices.append(td.text.strip())
    else:
        quantities.append(td.text.strip())
    i +=1

# %%
prices,quantities
# Out:
# (['900.65 EGP',
#   '4503.27 EGP',
#   '9006.54 EGP',
#   '18013.09 EGP',
#   '36026.17 EGP',
#   '45032.72 EGP',
#   '90065.43 EGP',
#   '900654.3 EGP'],
#  ['1    Gram Gold Price',
#   '5 Gram Gold Price',
#   '10 Gram Gold Price',
#   '20 Gram Gold Price',
#   '40 Gram Gold Price',
#   '50 Gram Gold Price',
#   '100 Gram Gold Price',
#   '1000 Gram Gold Price'])

# %%
pd.DataFrame({'price':prices,'Quantity':quantities})
# Out:
#           price              Quantity
# 0    900.65 EGP  1    Gram Gold Price
# 1   4503.27 EGP     5 Gram Gold Price
# 2   9006.54 EGP    10 Gram Gold Price
# 3  18013.09 EGP    20 Gram Gold Price
# 4  36026.17 EGP    40 Gram Gold Price
# 5  45032.72 EGP    50 Gram Gold Price
# 6  90065.43 EGP   100 Gram Gold Price
# 7  900654.3 EGP  1000 Gram Gold Price

# %% [markdown]
# ### or another method

# %%
df = pd.read_html('http://goldpricez.com/eg/gram')
df
# Out:
# [                       0                                                  1
#  0      Select a Currency  USD (US Dollar) EUR (Euro) GBP (Pound Sterling...
#  1  Select a Unit/ Weight  Ounce \tGram \tKilo  Tola Baht (15.244 Grams) ...
#  2   Select Karat/ Purity  Pure gold 24K (99.99% Pure Gold) 23K (96% Pure...,
#                     0             1
#  0     Current Price:    900.81 EGP
#  1   Today Low Price:    891.97 EGP
#  2  Today High Price:    902.26 EGP
#  3       Today 1 USD:  15.71012 EGP
#  4       Today 1 EGP:  $0.06365 USD,
#     Gold Unit Gold Rate in Egyptian Pound
#  0   Gram 24K                  900.65 EGP
#  1   Gram 23K                  863.13 EGP
#  2   Gram 22K                  825.60 EGP
#  3   Gram 21K                  788.07 EGP
#  4   Gram 18K                  675.49 EGP
#  5   Gram 16K                  600.44 EGP
#  6   Gram 14K                  525.38 EGP
#  7   Gram 12K                  450.33 EGP
#  8   Gram 10K                  375.27 EGP
# ...

# %%
df = pd.read_html('http://goldpricez.com/eg/gram')[-2]
df.columns = ['Unit','Price']
df.head()
# Out:
#                  Unit         Price
# 0   1 Gram Gold Price    900.65 EGP
# 1   5 Gram Gold Price   4503.27 EGP
# 2  10 Gram Gold Price   9006.54 EGP
# 3  20 Gram Gold Price  18013.09 EGP
# 4  40 Gram Gold Price  36026.17 EGP

# %%
df['Price'] = df.Price.apply(lambda x : x.split()[0])
df['Unit'] = df.Unit.apply(lambda x : x.split()[0])
df.head()
# Out:
#   Unit     Price
# 0    1    900.65
# 1    5   4503.27
# 2   10   9006.54
# 3   20  18013.09
# 4   40  36026.17

# %% [markdown]
# ## How to use Python requests to fake a browser visit a.k.a and generate User Agent? [stackoverflow](https://stackoverflow.com/questions/27652543/how-to-use-python-requests-to-fake-a-browser-visit-a-k-a-and-generate-user-agent) and [wikipedia](https://en.wikipedia.org/wiki/User_agent)

# %%
import requests
url = 'http://www.ichangtou.com/#company:data_000008.html'
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
response = requests.get(url, headers=headers)
print(response.content)

# %% [markdown]
# [Stackoverflow](https://stackoverflow.com/questions/16063499/how-to-read-useragent-details)
#
# ## Syntax
#
#     User-Agent: <product> / <product-version> <comment>
#
#     Common format for web browsers:
#
#     User-Agent: Mozilla/<version> (<system-information>) <platform> (<platform-details>) <extensions>
#
# ## Directives
#
#     <product>
#       A product identifier
#
#     <product-version>
#       A version number of the product.
#
#     <comment>
#       Zero or more comments containing sub product information, for example.
#
# # Examples
# ## Firefox UA string:
#
# Mozilla/5.0 (Windows NT 6.1; Win64; x64; rv:47.0) Gecko/20100101 Firefox/47.0
# Mozilla/5.0 (Macintosh; Intel Mac OS X x.y; rv:42.0) Gecko/20100101 Firefox/42.0
#
# ## Chrome UA string:
#
#     The Chrome (or Chromium/blink-based engines) user agent string is similar to the Firefox format. For compatibility, it adds strings like "KHTML, like Gecko" and "Safari".
#
# Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/51.0.2704.103 Safari/537.36
#
# ## Safari UA string:
#
# Mozilla/5.0 (iPhone; CPU iPhone OS 10_3_1 like Mac OS X) AppleWebKit/603.1.30 (KHTML, like Gecko) Version/10.0 Mobile/14E304 Safari/602.1
#
# ## Internet Explorer UA string:
#
# Mozilla/5.0 (compatible; MSIE 9.0; Windows Phone OS 7.5; Trident/5.0; IEMobile/9.0)
